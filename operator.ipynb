# %%
##arithmatic operator
a=10
b=15
result =a+b
print(result)
# Out:
# 25

# %%
##Arithmetic operation
a=10
b=5

add =a+b
sub =a-b
multi =a*b
div =a/b
floor_div =a//b
modulus =a%b
exponent =a**b

print(add)
print(sub)
print(multi)
print(div)
print(floor_div)
print(modulus)
print(exponent)
# Out:
# 15
# 5
# 50
# 2.0
# 2
# 0
# 100000

# %%
##comparison operator
## == equal to 
a=10
b=10
a==b
# Out:
# True

# %%
str1="rahul"
str2="rahul"

str1==str2
# Out:
# True

# %%
## not equal to !=
str1!=str2
# Out:
# False

# %%
str3="Rahul"
str4="rahul"

str3!=str4
# Out:
# True

# %%
## greater than >
num1=45
num2=55
num1>num2
# Out:
# False

# %%
## less than <
num1=45
num2=55
num1<num2
# Out:
# True

# %%
## greater than or equal to >=
num1=45
num2=45
num1>=num2
# Out:
# True

# %%
## less than or equal to >=
num1=45
num2=55
num1<=num2
# Out:
# True

# %%
##logical operator
## and,or,not oerator
# AND operator
x =True
y =True

result =x and y
print(result)
# Out:
# True

# %%
x =False
y =True

result =x and y
print(result)
# Out:
# False

# %%
## OR operator

x =False
y =True

result =x or y
print(result)
# Out:
# True
