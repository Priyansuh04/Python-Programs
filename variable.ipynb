# %%
a = 100

# %%
## declaring and assigning variables 
age = 35
height = 6.2
name ="ram"
is_student = True

## printing the variables

print("age :", age)
print("height :",height)
print("name :",name)
# Out:
# age : 35
# height : 6.2
# name : ram

# %%
## Naming convention
## variable names should be distriptive 
## they must be start with a letter or an '_' and contain letter,number and underscores
## variable name case sensitive 

## valid variables names 
first_name = "raj"
last_name ="kumar"

# %%
## invalid variables names
## 8age =45
## first-name ="ram"
@name ="raj"
# Out:
#   Cell In[3], line 4
#     @name ="raj"
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
## case sensitive
name="rajkumar"
Name="ramcaharan"
name==Name
# Out:
# False

# %%
## understanding variable types 
## python is dynamically typed, type of a variable is determine at runtime 
## type checking 
age= 25          #int
height =6.2      #float
name="krish"     #str
is_student=True  #bool

print(type(name))
# Out:
# <class 'str'>

# %%
age = 36
print(type(age))
## type conversion
age_str=str(age)
print(age_str)
print(type(age_str))
# Out:
# <class 'int'>
# 36
# <class 'str'>

# %%
age ='25'
print(type(int(age)))
# Out:
# <class 'int'>

# %%
name="anshul"
int(name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 name="anshul"
# ----> 2 int(name)
#
# ValueError: invalid literal for int() with base 10: 'anshul'

# %%
height =5.11
type(height)
int(height)
# Out:
# float

# %%
## dynamic typing
## pyhton allows the types of a variable to changes as the program executes

var =10              #int
print(var,type(var))

var ="hello"         #str
print(var,type(var))

var =3.14            #float
print(var,type(var))
# Out:
# 10 <class 'int'>
# hello <class 'str'>
# 3.14 <class 'float'>

# %%
##input

age =input("what is the age")
print(age)
