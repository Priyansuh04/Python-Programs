# %%
##arithmatic operator
a=10
b=15
result =a+b
print(result)
# Out:
# 25

# %%
##Arithmetic operation
a=10
b=5

add =a+b
sub =a-b
multi =a*b
div =a/b
floor_div =a//b
modulus =a%b
exponent =a**b

print(add)
print(sub)
print(multi)
print(div)
print(floor_div)
print(modulus)
print(exponent)

# %%
##comparison operator
## == equal to 
a=10
b=10
a==b

# %%
str1="rahul"
str2="rahul"

str1==str2

# %%
## not equal to !=
str1!=str2

# %%
str3="Rahul"
str4="rahul"

str3!=str4

# %%
## greater than >
num1=45
num2=55
num1>num2

# %%
## less than <
num1=45
num2=55
num1<num2

# %%
## greater than or equal to >=
num1=45
num2=45
num1>=num2

# %%
## less than or equal to >=
num1=45
num2=55
num1<=num2

# %%
##logical operator
## and,or,not oerator
# AND operator
x =True
y =True

result =x and y
print(result)

# %%
x =False
y =True

result =x and y
print(result)

# %%
## OR operator

x =False
y =True

result =x or y
print(result)

# %%
## Not operator
x = True
not x

# %%
## simple calculator 
num1=float(input("enter the first number :"))
num2=float(input("enter the second number :"))

Addition = num1 + num2
Subtraction = num1 - num2
Multiplication = num1 * num2
Division = num1 / num2
Floor_division = num1 // num2
modulus = num1 % num2
exponentiation = num1 ** num2

print("Addition:",Addition )
print("Subtraction :",Subtraction)
print("Multiplication:",Multiplication)
print("Division :",Division)
print("Floor_division :",Floor_division)
print("modulus :",modulus)
print("exponentiation :",exponentiation)
# Out:
# Addition: 40.0
# Subtraction : 16.0
# Multiplication: 336.0
# Division : 2.3333333333333335
# Floor_division : 2.0
# modulus : 4.0
# exponentiation : 2.322182650892124e+17
