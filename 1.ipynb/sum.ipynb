# %%
a = int(input("enter the number "))
b = int(input("enter the number "))

sum = a + b
print("sum of the number ",sum)
# Out:
# sum of the number  35

# %%
a = int(input("enter the number "))
b = int(input("enter the number "))
## create calculate
add = a + b
sub = a - b
mul = a * b
div = a/b


print("addition the number",add)
print("subtraction the number",sub)
print("multiply the number",mul)
print("divide the number",div)
# Out:
# addition the number 17
# subtraction the number 1
# multiply the number 72
# divide the number 1.125
