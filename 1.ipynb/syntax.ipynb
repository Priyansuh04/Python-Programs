# %%
## basic rules  syntax in python

## this is a single line comment
print("hello world")
# Out:
# hello world

# %%
## case sensitivity - python is case sensititive
name ="python"
Name ="progarmming"
print(name)
print(Name)
# Out:
# python
# progarmming

# %%
## indentation :
## pyhton uses indentation to define a block of code . consistent use of spaces(commonly 4) or a tab is required .

# %%
age = 32
if age>30:
    print(age)

print(age)
# Out:
# 32
# 32

# %%
## line continuation
total = 1+2+3+4+5+6+7+\
4+5+6

print(total)
# Out:
# 43

# %%
## multiple statement on a single line
x =5;y =10;z=x+y
print(z)
# Out:
# 15

# %%
## understanding semantics in python 
## variable assignment 
age =32 ## age is integer 
name = "xyz" ## name is a string
type(age)
# Out:
# int

# %%
## type interence 
variable = 10
print(type(variable))
variable = "xyz"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
age = 32
if age>30:
    print(age)
# Out:
# 32

# %%
## code example of indentation 
if True:
    print("correct indentation")
    if False:
        print("this is not print")
    print("thid will print")
print("outside the if block")
# Out:
# correct indentation
# thid will print
# outside the if block

# %%
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 a=b
#
# NameError: name 'b' is not defined
