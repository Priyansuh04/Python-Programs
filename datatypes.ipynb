# %%
## integer example
age=25
type(age)
# Out:
# int

# %%
##floating point datatypes
height=5.10
print(height)
print(type(height))
# Out:
# 5.1
# <class 'float'>

# %%
##string datatypes example
name = "rahul"
print(name)
print(type(name))
# Out:
# rahul
# <class 'str'>

# %%
##boolean datatypes 
is_true =True
type(is_true)
# Out:
# bool

# %%
a=10
b=10

print(a==b)
type(a==b)
# Out:
# True
# bool

# %%
##common error
result ="hello"+5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 ##common error
# ----> 2 result ="hello"+5
#
# TypeError: can only concatenate str (not "int") to str

# %%
result ="hello"+str(5) #"5"
print(result)
# Out:
# hello5
