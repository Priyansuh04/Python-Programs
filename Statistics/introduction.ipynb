# %% [markdown]
# ## Statistics
# #### Data: Statistics is the science of collecting,orzanizing,and analyzing data.
# #### Used in decision making
# #### Data:"Facts or pieces of information"-Measured,Collected,Analyzed

# %% [markdown]
# ### Application
# data exploration and summarize ,model buling and validation ,statistical analysis ,hypothesis testing , optimization and efficency ,reporting

# %% [markdown]
# statistical analysis-,sample data , population date

# %% [markdown]
# ## Types of statistics

# %% [markdown]
# ### 1 Descriptive Statistics
# Descriptive Statistics involves methods for summarizing and organizing data to make it understandable. this type of statistics helps to describe the basic feature of the data in a study.

# %% [markdown]
# ### 2 Inferential Statistics
# Inferential satistics involves methods for making predictions or inferences about a population based on a sample of data. it allows for hypothesis testing, estimation, and drawing conclusions.

# %% [markdown]
# ## Population And Sample Data

# %% [markdown]
# ### Population
# A Population is the entire set of individuals or objects of in a paricular study. it includes all members of a defined group that we are studying or collecting information on.

# %% [markdown]
# ### Charteristics of population
# complete set ,
# parameter ,
# population mean ,
# poppulation variance

# %% [markdown]
# example: population in a school study ,
# population in market research ,
# population in a medical study

# %% [markdown]
# ### Sample Data
# A Sample is a subset of the population that is used to represent the entire group. sampling involves selecting a group of individual or observations from the population to draw conclusions about the whole population.

# %% [markdown]
# ### Chateristics of sample data
# subset ,statistic ,random sampling

# %% [markdown]
# example: sample in a school , sample in market research ,
# sample in a medical study

# %% [markdown]
# ## Types of sampling Techniques
# ### 1 Probality Sampling , 2 Non Probality Sampling

# %% [markdown]
# ### Probality Sampling

# %% [markdown]
# ### a. Simple random sampling
# Every member of the population has equal chance of being selected.

# %% [markdown]
# ### b. Systematic sampling
# Select every nth member of the population after a random starting point.

# %% [markdown]
# ### c. Statisfied sampling
# Divide the population into strata (groups) based omn specific charteristic and then randomly sampling from each strata.

# %% [markdown]
# ### d. Cluster sampling
# Divide the population into clusters, randomly selecting clusters,then sampling all the members from the selected clusters.

# %% [markdown]
# ### e. Milti stage sampling
# Combining several sampling methods usually involves selecting clusters,then randomly sampling with in those cluster.

# %% [markdown]
# ### Non probality sampling
# select individuals who are easiest to  reach.

# %% [markdown]
# ### a. Convenience sampling
# selecting individual who are easiest to reach.

# %% [markdown]
# ### b. Dudgemental (purposive) sampling
# select individual based on researcher's judgement - useful or reprentative

# %% [markdown]
# ### c. Snowball sampling
# existing study subjects recruit future subjects from among their acquiantances.

# %% [markdown]
# ### d. Quota sampling
# selecting the sampling technique depends on use cases. age,group,gender,caste

# %% [markdown]
# ### Types of data
# #### 1 quantitative (numerical data)
# #### 2 qualitative (categorial data)

# %% [markdown]
# ### 1 quantitative
# #### a. discrete (whole numbers) eg: no. of bank accounts
# #### b. continuous (any value) eg: temperature ,speed,height,weight

# %% [markdown]
# ### 2 qualitative
# #### a. nominal (no rank) eg: gender -m,f, blood group, pincode
# #### b. ordinal (rank) eg: customer feedback ,good for 1,better for 2, bad for 3.

# %% [markdown]
# ### Scale of measurement of data
# the scales of measurement describe the nature of informationwithin the values assigned to variables.

# %% [markdown]
# ### 4 primary scale of measurement
# #### 1 nominal scale
# #### 2 ordinal scale
# #### 3 interval scale
# #### 4 ratio scale

# %% [markdown]
# ### 1 Nominal sacle
# this classifies data into distinct categorical that do not have an intrinsic order qualitative /categorical data.

# %% [markdown]
# ### Characteristic
# #### i. data is categorized based on lables,names or qualifies.
# #### ii. categories are mutually exclusive
# #### iii. no logical order among categories [no rank]
# example:  genger- m , f. colors ,red, blue, pink

# %% [markdown]
# ### 2 ordinal scale
# this scale classifies the data into categories that can be ranked or ordered

# %% [markdown]
# ### characteristic
# #### i. data is categorial and ranked in a specific order
# #### ii. the interval between ranks are not necenarily equal
# example: equcation level -high school,bachelor,masters,doctorate.

# %% [markdown]
# ### 3 Interval scale
# data: the interval scale not only categorizes and orders but also specify the exact difference between intervals.it lacks a true zero point.

# %% [markdown]
# ### Characteristic
# #### i. data is ordered with consistent interval between values.
# #### ii. allows for meaningful comparison of difference.[ratio can not be measured]
# #### iii. no  true zero point.
# example-temerature in fahrenheit -10'f, 20'f, 30'f. 20-10=10, 30-20=10 , 0'f " no temperature"

# %% [markdown]
# ### Ratio scale
# #### the order matters
# #### differencess are measurable[ratio can be measured]
# #### containts a 0 starting point
# example - student marks in a class
# 0,30,45,60,75,90
# ratio-90/30=3:1
