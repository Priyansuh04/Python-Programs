# %% [markdown]
# ## Statistics
# #### Data: Statistics is the science of collecting,orzanizing,and analyzing data.
# #### Used in decision making
# #### Data:"Facts or pieces of information"-Measured,Collected,Analyzed

# %% [markdown]
# eg: weight of students in the class
# { 60kg, 50kg, 45kg, 30kg, -------}

# %% [markdown]
# IQ of the students in class
# { 100, 90, 99, 98 -----}

# %% [markdown]
# ##### precced and analyze the data
#
# House Price Dataset
# Area, No of Rooms, Price
# 1000, 2, 45lakhs
# 1250, 3, 50lakhs
# ----, -, -------

# %% [markdown]
# Analyzing his data ,
# data scientist ,-
# model ,-
# price

# %% [markdown]
# data  analyst ,-report , visualization -,project ,meaning decisions

# %% [markdown]
# ### application
# data exploration and summarize ,model buling and validation ,statistical analysis ,hypothesis testing , optimization and efficency ,reporting

# %% [markdown]
# statistical analysis-,sample data , population date
