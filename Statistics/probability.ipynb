# %% [markdown]
# ### Probability Distribution Functions
# #### probability distribution functions describe how the probalities are distributed over the values of a random variable.

# %% [markdown]
# #### Types of probability distribution functions
# ##### Probability Mass function (PMF):Used for discrete random variable.
# ##### Probability density function(PDF):Used for continuous random variable
