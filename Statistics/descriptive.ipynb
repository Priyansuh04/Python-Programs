# %% [markdown]
# ### Measure of central tendency
# #### measure of central tendency are statistical matrics that describe the central point aor typical value of a dataset. they provide a single value that summarizes a set of data by identifying the central position with in tat datset.

# %% [markdown]
# #### 1. Mean
# #### 2. Median
# #### 3. Mode

# %% [markdown]
# #### 1. Mean
# #### mean is the sum of all values divide by the number of values.

# %% [markdown]
# population mean(mu) , sample mean(x bar)

# %% [markdown]
# ### Charteristics
# #### affected by extreme outliers
# #### used for interval and ratio data

# %% [markdown]
# ### 2. Median
# #### the median is the middle value in a dataset when the values are arranged in ascending or descending order.

# %% [markdown]
# ### Charteristics
# #### not affected by extreme outliers
# #### used for ordinal , interval and ratio data

# %% [markdown]
# ### 3 Mode
# #### data: the mode is the value that appears most frequency in a dataset.

# %% [markdown]
# ### Charteristics
# #### not affected by extreme  values
# #### used for nominal, ordinal , interval and ratio data.

# %% [markdown]
# ### Choosing the appropriate measure
# #### 1. Mean: Best used when data is symmertrically distributed without outliers. provides a mathematical average, which is useful for further statistical calculations.
# #### 2. Median: Best used when is data is skewed or contains outliers. provides the midddle value,  which better represents the center of a skewed dataset.
# #### 3. Mode: Best used for categorical data to identify the most common category. also useful for identifying the most frequent value in ordinal, interval, or ratio data.

# %% [markdown]
# ### Measure of dispersion
# #### Measure of dispersion describe the spread or variability of a dataset. they indicate how much the values in a dataset different from the central tendency.

# %% [markdown]
# ### Common measure of dispersion
# #### 1.Range
# #### 2.variance
# #### 3.Standard Deviation
# #### 4.Interquartile Range(IQR)

# %% [markdown]
# ### 1. Range
# #### Range is the difference between the maximum and minimum value in a dataset.

# %% [markdown]
# ### Characteristic
# #### 1. simple to calculate
# #### 2. sensitive to outliers
# #### 3. rough measure of dispersion

# %% [markdown]
# ### Variance
# #### variance mesure the average squared deviation of each values from thr mean. it provides a sense of how much the values in a dataset vary.

# %% [markdown]
# ### Characterisyic
# #### 1. provide a precise measure of variability
# #### 2. units are squared of the orinial data units
# #### 3. more sensitive to outliers than the range

# %% [markdown]
# ### Standard deviation
# #### The satandard deviation is the square root of the variance.

# %% [markdown]
# ### Characteristic
# #### provides a clear measure of spread in the same units as the data
# #### sensitive to outliers
