# %% [markdown]
# ## Reading data from different sources

# %%
import pandas as pd
from io import StringIO
Data='{"employee_name": "james", "email": "james@gmail.com", "job_profile": [{title1}: "team lead", "title2": "Sr. devloper"]}'
df=pd.read_csv(StringIO(Data))
print(df)
# Out:
# Empty DataFrame
# Columns: [{"employee_name": "james",  "email": "james@gmail.com",  "job_profile": [{title1}: "team lead",  "title2": "Sr. devloper"]}]
# Index: []

# %%
import pandas as pd
from io import StringIO

data = '''
{
  "employee_name": "james",
  "email": "james@gmail.com",
  "job_profile": [
    {"title1": "team lead", "title2": "Sr. developer"}
  ]
}
'''

pd.read_json(StringIO(data))
# Out:
#   employee_name            email  \
# 0         james  james@gmail.com
#
#                                          job_profile
# 0  {'title1': 'team lead', 'title2': 'Sr. develop...

# %%
df=pd.read_json(StringIO(data))
print(df)
# Out:
#   employee_name            email  \
# 0         james  james@gmail.com
#
#                                          job_profile
# 0  {'title1': 'team lead', 'title2': 'Sr. develop...

# %%
df.to_json
# Out:
# <bound method NDFrame.to_json of   employee_name            email  \
# 0         james  james@gmail.com
#
#                                          job_profile
# 0  {'title1': 'team lead', 'title2': 'Sr. develop...  >

# %%
df.to_json(orient="index")
# Out:
# '{"0":{"employee_name":"james","email":"james@gmail.com","job_profile":{"title1":"team lead","title2":"Sr. developer"}}}'

# %%
df.to_json(orient="records")
# Out:
# '[{"employee_name":"james","email":"james@gmail.com","job_profile":{"title1":"team lead","title2":"Sr. developer"}}]'

# %%
import pandas as pd

data = [
    [1, 10, 100],
    [2, 20, 200],
    [3, 30, 300],
    [4, 40, 400]
]

# create dataframe
df = pd.DataFrame(data, columns=["A", "B", "C"])

# write to csv
df.to_csv("numbers.csv", index=False)

# read from csv
daf = pd.read_csv("numbers.csv")
print(daf)
# Out:
#    A   B    C
# 0  1  10  100
# 1  2  20  200
# 2  3  30  300
# 3  4  40  400

# %%
daf.head()
# Out:
#    A   B    C
# 0  1  10  100
# 1  2  20  200
# 2  3  30  300
# 3  4  40  400

# %%
df = pd.read_csv("numbers.csv")
print(df)
# Out:
#    A   B    C
# 0  1  10  100
# 1  2  20  200
# 2  3  30  300
# 3  4  40  400

# %%
import pandas as pd

# read csv
df = pd.read_csv("numbers.csv")

# save as excel
df.to_excel("numbers.xlsx", index=False)

# read excel
df_excel = pd.read_excel("numbers.xlsx")
print(df_excel)
# Out:
#    A   B    C
# 0  1  10  100
# 1  2  20  200
# 2  3  30  300
# 3  4  40  400

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\priya\onedrive\desktop\python\venv\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\priya\onedrive\desktop\python\venv\lib\site-packages (from openpyxl) (2.0.0)

# %%
# !pip install xlsxwriter
# Out:
# Requirement already satisfied: xlsxwriter in c:\users\priya\onedrive\desktop\python\venv\lib\site-packages (3.2.9)

# %%
df_excel.to_pickle("df_excel")

# %%
pd.read_pickle("df_excel")
# Out:
#    A   B    C
# 0  1  10  100
# 1  2  20  200
# 2  3  30  300
# 3  4  40  400
